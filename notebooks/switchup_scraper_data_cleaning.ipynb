# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 5-6 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {   
'ironhack' : 10828,
'app-academy' : 10525,
'springboard' : 11035    
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# ironhack
# app-academy
# springboard

# %%
comments
# Out:
#           id           name  anonymous hostProgramName  graduatingYear  \
# 0     306372  Sergio Burgos      False            None          2023.0
# 1     306215      Anonymous       True            None          2023.0
# 2     306068      Anonymous       True            None          2023.0
# 3     305297    Utku Cikmaz      False            None          2023.0
# 4     305278   Nirmal Hodge      False            None          2023.0
# ...      ...            ...        ...             ...             ...
# 1560  234894   Stephanie S.      False            None          2015.0
# 1561  234877       Joe Fang      False            None          2015.0
# 1562  234838          Zeina      False            None          2016.0
# 1563  242681           Jean      False            None          2016.0
# 1564  234178            Ben      False            None          2016.0
#
#       isAlumni                         jobTitle  \
# 0        False         International Negotiator
# 1         True
# 2        False           Full stack development
# 3        False         Full Stack Web Developer
# 4        False                 Product Designer
# ...        ...                              ...
# 1560      True          Website Manager-UX Lead
# 1561      True                      UX Designer
# 1562      True          Senior Graphic Designer
# 1563      True  Lead Designer/Creative Director
# 1564      True                             None
#
#                                                 tagline  \
# 0                   The Most Intense Academic Challenge
# 1        Transformative Experience: My Time at Ironhack
# 2                                       Now I can do it
# 3                                           It was good
# 4                               Ironhack 100% Worth It!
# ...                                                 ...
# 1560              Excellent and comprehensive UX course
# 1561        Springboard helped me start my career in UX
# 1562                                 Highly recommended
# 1563    A way to stay current for the highly motivated!
# 1564  Springboard is an excellent course for self dr...
#
#                                                    body  \
# 0     <span class="truncatable"><p></p><p>After comp...
# 1     <span class="truncatable"><p></p><p>Pros: 1)In...
# 2     <span class="truncatable"><p></p><p>7 months a...
# 3     <span class="truncatable"><p></p><p>The course...
# 4     <span class="truncatable"><p></p><p>I joined t...
# ...                                                 ...
# 1560  <span class="truncatable"><p>The UX Design Wor...
# 1561  <span class="truncatable"><p>Just some backgro...
# 1562  <span class="truncatable"><p>I enjoyed the pro...
# 1563  <span class="truncatable"><p>This was my first...
# 1564  <span class="truncatable"><p>I really enjoyed ...
#
#                                                 rawBody  ...   queryDate  \
# 0     <p>After completing my Data Analytics Bootcamp...  ...  2023-11-10
# 1     <p>Pros: 1)Intensive Learning 2)Real-World Pro...  ...  2023-11-06
# 2     <p>7 months ago, I only had an idea about html...  ...  2023-10-31
# 3     <p>The course was great. Especially, Luis is a...  ...  2023-10-02
# 4     <p>I joined the UX/ UI Bootcamp and to be hone...  ...  2023-09-30
# ...                                                 ...  ...         ...
# 1560  The UX Design Workshop gave me a great underst...  ...  2016-12-15
# 1561  Just some background information on myself, I ...  ...  2016-12-15
# 1562  I enjoyed the program very much, gained a lot ...  ...  2016-12-15
# 1563  This was my first online experience and it did...  ...  2016-12-12
# 1564  I really enjoyed my time with the Springboard ...  ...  2016-12-10
#
#                        program             user overallScore comments overall  \
# 0      Data Analytics Bootcamp  {'image': None}          3.3       []     3.0
# 1     Web Development Bootcamp  {'image': None}          4.0       []     4.0
# 2                         None  {'image': None}          5.0       []     5.0
# 3     Web Development Bootcamp  {'image': None}          4.0       []     5.0
# 4        UX/UI Design Bootcamp  {'image': None}          5.0       []     5.0
# ...                        ...              ...          ...      ...     ...
# 1560                 UX Design  {'image': None}          5.0       []     5.0
# 1561                 UX Design  {'image': None}          5.0       []     5.0
# 1562                 UX Design  {'image': None}          3.7       []     4.0
# 1563                 UX Design  {'image': None}          5.0       []     5.0
# 1564                 UX Design  {'image': None}          4.7       []     5.0
#
#      curriculum jobSupport                                        review_body  \
# 0           3.0        4.0  After completing my Data Analytics Bootcamp wi...
# 1           4.0        4.0  Pros: 1)Intensive Learning 2)Real-World Projec...
# 2           5.0        5.0  7 months ago, I only had an idea about html an...
# 3           3.0        4.0  The course was great. Especially, Luis is a gr...
# 4           5.0        5.0  I joined the UX/ UI Bootcamp and to be honest ...
# ...         ...        ...                                                ...
# 1560        5.0        5.0  The UX Design Workshop gave me a great underst...
# 1561        5.0        5.0  Just some background information on myself, I ...
# 1562        4.0        3.0  I enjoyed the program very much, gained a lot ...
# 1563        5.0        5.0  This was my first online experience and it did...
# 1564        5.0        4.0  I really enjoyed my time with the Springboard ...
#
#            school
# 0        ironhack
# 1        ironhack
# 2        ironhack
# 3        ironhack
# 4        ironhack
# ...           ...
# 1560  springboard
# 1561  springboard
# 1562  springboard
# 1563  springboard
# 1564  springboard
#
# [4048 rows x 21 columns]

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# C:\Users\Win10 Pro x64\AppData\Local\Temp\ipykernel_14148\1181667300.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# app-academy
# C:\Users\Win10 Pro x64\AppData\Local\Temp\ipykernel_14148\1181667300.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)
# springboard
# C:\Users\Win10 Pro x64\AppData\Local\Temp\ipykernel_14148\1181667300.py:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   locations_df = json_normalize(locations)

# %%
locations_list
# Out:
# [      id               description  country.id   country.name country.abbrev  \
#  0  15901           Berlin, Germany        57.0        Germany             DE
#  1  16022       Mexico City, Mexico        29.0         Mexico             MX
#  2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
#  3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
#  4  16109             Paris, France        38.0         France             FR
#  5  16375  Miami, FL, United States         1.0  United States             US
#  6  16376             Madrid, Spain        12.0          Spain             ES
#  7  16377          Barcelona, Spain        12.0          Spain             ES
#  8  16709          Lisbon, Portugal        28.0       Portugal             PT
#  9  17233                    Online         NaN            NaN            NaN
#
#     city.id    city.name city.keyword  state.id state.name state.abbrev  \
#  0  31156.0       Berlin       berlin       NaN        NaN          NaN
#  1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
#  2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
#  3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
#  4  31136.0        Paris        paris       NaN        NaN          NaN
#  5     31.0        Miami        miami      11.0    Florida           FL
#  6  31052.0       Madrid       madrid       NaN        NaN          NaN
#  7  31170.0    Barcelona    barcelona       NaN        NaN          NaN
#  8  31075.0       Lisbon       lisbon       NaN        NaN          NaN
#  9      NaN          NaN          NaN       1.0     Online       Online
#
#    state.keyword    school  school_id
#  0           NaN  ironhack      10828
#  1           NaN  ironhack      10828
#  2           NaN  ironhack      10828
#  3           NaN  ironhack      10828
#  4           NaN  ironhack      10828
#  5       florida  ironhack      10828
#  6           NaN  ironhack      10828
#  7           NaN  ironhack      10828
#  8           NaN  ironhack      10828
#  9        online  ironhack      10828  ,
#        id                       description  country.id   country.name  \
#  0  15704  San Francisco, CA, United States         1.0  United States
#  1  15705  New York City, NY, United States         1.0  United States
#  2  15862                            Online         NaN            NaN
#
#    country.abbrev  state.id  state.name state.abbrev state.keyword  city.id  \
#  0             US         6  California           CA    california     13.0
#  1             US        34    New York           NY      new-york   1507.0
#  2            NaN         1      Online       Online        online      NaN
#
#         city.name   city.keyword       school  school_id
#  0  San Francisco  san-francisco  app-academy      10525
#  1            NYC  new-york-city  app-academy      10525
#  2            NaN            NaN  app-academy      10525  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  16013      Online         1     Online       Online        online
#
#          school  school_id
#  0  springboard      11035  ]

# %%
locations = pd.concat(locations_list)
locations
# Out:
#       id                       description  country.id   country.name  \
# 0  15901                   Berlin, Germany        57.0        Germany
# 1  16022               Mexico City, Mexico        29.0         Mexico
# 2  16086            Amsterdam, Netherlands        59.0    Netherlands
# 3  16088                 Sao Paulo, Brazil        42.0         Brazil
# 4  16109                     Paris, France        38.0         France
# 5  16375          Miami, FL, United States         1.0  United States
# 6  16376                     Madrid, Spain        12.0          Spain
# 7  16377                  Barcelona, Spain        12.0          Spain
# 8  16709                  Lisbon, Portugal        28.0       Portugal
# 9  17233                            Online         NaN            NaN
# 0  15704  San Francisco, CA, United States         1.0  United States
# 1  15705  New York City, NY, United States         1.0  United States
# 2  15862                            Online         NaN            NaN
# 0  16013                            Online         NaN            NaN
#
#   country.abbrev  city.id      city.name   city.keyword  state.id  state.name  \
# 0             DE  31156.0         Berlin         berlin       NaN         NaN
# 1             MX  31175.0    Mexico City    mexico-city       NaN         NaN
# 2             NL  31168.0      Amsterdam      amsterdam       NaN         NaN
# 3             BR  31121.0      Sao Paulo      sao-paulo       NaN         NaN
# 4             FR  31136.0          Paris          paris       NaN         NaN
# 5             US     31.0          Miami          miami      11.0     Florida
# 6             ES  31052.0         Madrid         madrid       NaN         NaN
# 7             ES  31170.0      Barcelona      barcelona       NaN         NaN
# 8             PT  31075.0         Lisbon         lisbon       NaN         NaN
# 9            NaN      NaN            NaN            NaN       1.0      Online
# 0             US     13.0  San Francisco  san-francisco       6.0  California
# 1             US   1507.0            NYC  new-york-city      34.0    New York
# 2            NaN      NaN            NaN            NaN       1.0      Online
# 0            NaN      NaN            NaN            NaN       1.0      Online
#
#   state.abbrev state.keyword       school  school_id
# 0          NaN           NaN     ironhack      10828
# 1          NaN           NaN     ironhack      10828
# 2          NaN           NaN     ironhack      10828
# 3          NaN           NaN     ironhack      10828
# 4          NaN           NaN     ironhack      10828
# 5           FL       florida     ironhack      10828
# 6          NaN           NaN     ironhack      10828
# 7          NaN           NaN     ironhack      10828
# 8          NaN           NaN     ironhack      10828
# 9       Online        online     ironhack      10828
# 0           CA    california  app-academy      10525
# 1           NY      new-york  app-academy      10525
# 2       Online        online  app-academy      10525
# 0       Online        online  springboard      11035

# %%
courses = pd.concat(courses_list)
courses.head(10)
# Out:
#                                 courses       school  school_id
# 0               Cyber Security Bootcamp     ironhack      10828
# 1               Cybersecurity Part-Time     ironhack      10828
# 2               Data Analytics Bootcamp     ironhack      10828
# 3              Data Analytics Part-Time     ironhack      10828
# 4                 UX/UI Design Bootcamp     ironhack      10828
# 5                UX/UI Design Part-Time     ironhack      10828
# 6              Web Development Bootcamp     ironhack      10828
# 7             Web Development Part-Time     ironhack      10828
# 0  16-week Software Engineering Program  app-academy      10525
# 1                         Bootcamp Prep  app-academy      10525

# %%
badges = pd.concat(badges_list)
badges
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 0          <p>School offers fully online courses</p>  app-academy      10525
# 1  <p>School offers part-time and evening classes...  app-academy      10525
# 2             <p>School guarantees job placement</p>  app-academy      10525
# 0          <p>School offers fully online courses</p>  springboard      11035
# 1  <p>School offers part-time and evening classes...  springboard      11035
# 2             <p>School guarantees job placement</p>  springboard      11035

# %%
# any data cleaning still missing here? take a look at the description
schools = pd.concat(schools_list)
schools.head()
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  www.springboard.com/?utm_source=switchup&utm_m...
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>Founded in 2012, ...
# 0  <span class="truncatable"><p>Springboard is an...
#
#                                              LogoUrl       school  school_id
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...     ironhack      10828
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  app-academy      10525
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  springboard      11035

# %%
locations
# Out:
#       id                       description  country.id   country.name  \
# 0  15901                   Berlin, Germany        57.0        Germany
# 1  16022               Mexico City, Mexico        29.0         Mexico
# 2  16086            Amsterdam, Netherlands        59.0    Netherlands
# 3  16088                 Sao Paulo, Brazil        42.0         Brazil
# 4  16109                     Paris, France        38.0         France
# 5  16375          Miami, FL, United States         1.0  United States
# 6  16376                     Madrid, Spain        12.0          Spain
# 7  16377                  Barcelona, Spain        12.0          Spain
# 8  16709                  Lisbon, Portugal        28.0       Portugal
# 9  17233                            Online         NaN            NaN
# 0  15704  San Francisco, CA, United States         1.0  United States
# 1  15705  New York City, NY, United States         1.0  United States
# 2  15862                            Online         NaN            NaN
# 0  16013                            Online         NaN            NaN
#
#   country.abbrev  city.id      city.name   city.keyword  state.id  state.name  \
# 0             DE  31156.0         Berlin         berlin       NaN         NaN
# 1             MX  31175.0    Mexico City    mexico-city       NaN         NaN
# 2             NL  31168.0      Amsterdam      amsterdam       NaN         NaN
# 3             BR  31121.0      Sao Paulo      sao-paulo       NaN         NaN
# 4             FR  31136.0          Paris          paris       NaN         NaN
# 5             US     31.0          Miami          miami      11.0     Florida
# 6             ES  31052.0         Madrid         madrid       NaN         NaN
# 7             ES  31170.0      Barcelona      barcelona       NaN         NaN
# 8             PT  31075.0         Lisbon         lisbon       NaN         NaN
# 9            NaN      NaN            NaN            NaN       1.0      Online
# 0             US     13.0  San Francisco  san-francisco       6.0  California
# 1             US   1507.0            NYC  new-york-city      34.0    New York
# 2            NaN      NaN            NaN            NaN       1.0      Online
# 0            NaN      NaN            NaN            NaN       1.0      Online
#
#   state.abbrev state.keyword       school  school_id
# 0          NaN           NaN     ironhack      10828
# 1          NaN           NaN     ironhack      10828
# 2          NaN           NaN     ironhack      10828
# 3          NaN           NaN     ironhack      10828
# 4          NaN           NaN     ironhack      10828
# 5           FL       florida     ironhack      10828
# 6          NaN           NaN     ironhack      10828
# 7          NaN           NaN     ironhack      10828
# 8          NaN           NaN     ironhack      10828
# 9       Online        online     ironhack      10828
# 0           CA    california  app-academy      10525
# 1           NY      new-york  app-academy      10525
# 2       Online        online  app-academy      10525
# 0       Online        online  springboard      11035

# %% [markdown]
# # Locations DF Data Cleaning

# %%
locations.columns
# Out:
# Index(['id', 'description', 'country.id', 'country.name', 'country.abbrev',
#        'city.id', 'city.name', 'city.keyword', 'state.id', 'state.name',
#        'state.abbrev', 'state.keyword', 'school', 'school_id'],
#       dtype='object')

# %%
locations.drop(columns=['country.id','country.abbrev', 'city.id','city.keyword','state.id', 'state.name', 'state.abbrev', 'state.keyword'], inplace=True)
locations
# Out:
#       id                       description   country.name      city.name  \
# 0  15901                   Berlin, Germany        Germany         Berlin
# 1  16022               Mexico City, Mexico         Mexico    Mexico City
# 2  16086            Amsterdam, Netherlands    Netherlands      Amsterdam
# 3  16088                 Sao Paulo, Brazil         Brazil      Sao Paulo
# 4  16109                     Paris, France         France          Paris
# 5  16375          Miami, FL, United States  United States          Miami
# 6  16376                     Madrid, Spain          Spain         Madrid
# 7  16377                  Barcelona, Spain          Spain      Barcelona
# 8  16709                  Lisbon, Portugal       Portugal         Lisbon
# 9  17233                            Online            NaN            NaN
# 0  15704  San Francisco, CA, United States  United States  San Francisco
# 1  15705  New York City, NY, United States  United States            NYC
# 2  15862                            Online            NaN            NaN
# 0  16013                            Online            NaN            NaN
#
#         school  school_id
# 0     ironhack      10828
# 1     ironhack      10828
# 2     ironhack      10828
# 3     ironhack      10828
# 4     ironhack      10828
# 5     ironhack      10828
# 6     ironhack      10828
# 7     ironhack      10828
# 8     ironhack      10828
# 9     ironhack      10828
# 0  app-academy      10525
# 1  app-academy      10525
# 2  app-academy      10525
# 0  springboard      11035

# %% [markdown]
#   Renaming columns to match the column names in the MySQL DB

# %%
locations.rename(columns={"id": "location_id"}, inplace=True)

# %%
locations.columns = locations.columns.str.replace(".", "_")
locations
# Out:
# C:\Users\Win10 Pro x64\AppData\Local\Temp\ipykernel_14148\870817422.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   locations.columns = locations.columns.str.replace(".", "_")
#    location_id                       description   country_name  \
# 0        15901                   Berlin, Germany        Germany
# 1        16022               Mexico City, Mexico         Mexico
# 2        16086            Amsterdam, Netherlands    Netherlands
# 3        16088                 Sao Paulo, Brazil         Brazil
# 4        16109                     Paris, France         France
# 5        16375          Miami, FL, United States  United States
# 6        16376                     Madrid, Spain          Spain
# 7        16377                  Barcelona, Spain          Spain
# 8        16709                  Lisbon, Portugal       Portugal
# 9        17233                            Online            NaN
# 0        15704  San Francisco, CA, United States  United States
# 1        15705  New York City, NY, United States  United States
# 2        15862                            Online            NaN
# 0        16013                            Online            NaN
#
#        city_name       school  school_id
# 0         Berlin     ironhack      10828
# 1    Mexico City     ironhack      10828
# 2      Amsterdam     ironhack      10828
# 3      Sao Paulo     ironhack      10828
# 4          Paris     ironhack      10828
# 5          Miami     ironhack      10828
# 6         Madrid     ironhack      10828
# 7      Barcelona     ironhack      10828
# 8         Lisbon     ironhack      10828
# 9            NaN     ironhack      10828
# 0  San Francisco  app-academy      10525
# 1            NYC  app-academy      10525
# 2            NaN  app-academy      10525
# 0            NaN  springboard      11035

# %% [markdown]
# Replacing missing values with 'Online', because all of the missing values are in the rows with online courses

# %%
locations.fillna("Online", inplace=True)
locations
# Out:
#    location_id                       description   country_name  \
# 0        15901                   Berlin, Germany        Germany
# 1        16022               Mexico City, Mexico         Mexico
# 2        16086            Amsterdam, Netherlands    Netherlands
# 3        16088                 Sao Paulo, Brazil         Brazil
# 4        16109                     Paris, France         France
# 5        16375          Miami, FL, United States  United States
# 6        16376                     Madrid, Spain          Spain
# 7        16377                  Barcelona, Spain          Spain
# 8        16709                  Lisbon, Portugal       Portugal
# 9        17233                            Online         Online
# 0        15704  San Francisco, CA, United States  United States
# 1        15705  New York City, NY, United States  United States
# 2        15862                            Online         Online
# 0        16013                            Online         Online
#
#        city_name       school  school_id
# 0         Berlin     ironhack      10828
# 1    Mexico City     ironhack      10828
# 2      Amsterdam     ironhack      10828
# 3      Sao Paulo     ironhack      10828
# 4          Paris     ironhack      10828
# 5          Miami     ironhack      10828
# 6         Madrid     ironhack      10828
# 7      Barcelona     ironhack      10828
# 8         Lisbon     ironhack      10828
# 9         Online     ironhack      10828
# 0  San Francisco  app-academy      10525
# 1            NYC  app-academy      10525
# 2         Online  app-academy      10525
# 0         Online  springboard      11035

# %% [markdown]
# Saving table as .csv file

# %%
locations.to_csv("CSV//locations.csv",index = False, sep=";")

# %% [markdown]
# Data cleaning schools DF

# %%
schools
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  www.springboard.com/?utm_source=switchup&utm_m...
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>Founded in 2012, ...
# 0  <span class="truncatable"><p>Springboard is an...
#
#                                              LogoUrl       school  school_id
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...     ironhack      10828
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  app-academy      10525
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  springboard      11035

# %%
schools = schools[['school_id','school','website', 'LogoUrl', 'description']].copy()
schools['description'] = schools['description'].str.replace(r'(?<=<).*?(?=>)', '', regex = True)
schools['description'] = schools['description'].str.replace('<>', '', regex = True)
schools['description'] = schools['description'].str.replace('Read Less|Read More', '', regex = True)
#schools.reset_index(inplace = True, drop = True)
#schools.index += 1

schools.head()
# Out:
#    school_id       school                                            website  \
# 0      10828     ironhack                                www.ironhack.com/en
# 0      10525  app-academy                                      appacademy.io
# 0      11035  springboard  www.springboard.com/?utm_source=switchup&utm_m...
#
#                                              LogoUrl  \
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...
#
#                                          description
# 0  Ironhack is a global tech school with 9 campus...
# 0  Founded in 2012, App Academy is a world-renown...
# 0  Springboard is an online learning platform tha...

# %%
schools.to_csv("CSV//schools.csv",index = False, sep=";")

# %% [markdown]
# Data cleaning courses DF

# %%
courses.head(3)
# Out:
#                    courses    school  school_id
# 0  Cyber Security Bootcamp  ironhack      10828
# 1  Cybersecurity Part-Time  ironhack      10828
# 2  Data Analytics Bootcamp  ironhack      10828

# %%
column_replacements = {
    'courses': 'course'
}
# Using lambda function we can replace the column names: 
courses.rename(columns=lambda x: x.replace('courses', 'course'), inplace=True)
courses.rename(columns=column_replacements, inplace=True)

courses.head(3)
# Out:
#                     course    school  school_id
# 0  Cyber Security Bootcamp  ironhack      10828
# 1  Cybersecurity Part-Time  ironhack      10828
# 2  Data Analytics Bootcamp  ironhack      10828

# %%
courses.drop(columns='school', inplace=True)

# %% [markdown]
# Resetting Index so that we get unique values for each program and copying those in a new column

# %%
courses = courses[['course', 'school_id']].copy()
courses.reset_index(drop=True, inplace=True)
courses['index'] = courses.index + 1

courses
# Out:
#                                                course  school_id  index
# 0                             Cyber Security Bootcamp      10828      1
# 1                             Cybersecurity Part-Time      10828      2
# 2                             Data Analytics Bootcamp      10828      3
# 3                            Data Analytics Part-Time      10828      4
# 4                               UX/UI Design Bootcamp      10828      5
# 5                              UX/UI Design Part-Time      10828      6
# 6                            Web Development Bootcamp      10828      7
# 7                           Web Development Part-Time      10828      8
# 8                16-week Software Engineering Program      10525      9
# 9                                       Bootcamp Prep      10525     10
# 10                           Bootcamp Prep Self-Paced      10525     11
# 11  16-Week Online Full-Time Accelerated Software ...      10525     12
# 12   24-week Software Engineering Program (Full Time)      10525     13
# 13   48-week Software Engineering Program (Part Time)      10525     14
# 14                                   App Academy Open      10525     15
# 15                        Cyber Security Career Track      11035     16
# 16                        Data Analytics Career Track      11035     17
# 17                          Data Science Career Track      11035     18
# 18                     Data Science Career Track Prep      11035     19
# 19                          Front-End Web Development      11035     20
# 20                     Introduction to Data Analytics      11035     21
# 21                             Introduction to Design      11035     22
# 22                  Software Engineering Career Track      11035     23
# 23      Software Engineering Career Track Prep Course      11035     24
# 24           Software Engineering Foundations to Core      11035     25
# 25                            Tech Sales Career Track      11035     26
# 26                          UI/UX Design Career Track      11035     27
# 27                                    UX Career Track      11035     28

# %% [markdown]
# Renaming 'Index' column to 'course_id'

# %%
courses.rename(columns={'index': 'course_id'}, inplace=True)
courses = courses.reindex(columns=['course_id', 'course', 'school_id'])


courses.head(3)
# Out:
#    course_id                   course  school_id
# 0          1  Cyber Security Bootcamp      10828
# 1          2  Cybersecurity Part-Time      10828
# 2          3  Data Analytics Bootcamp      10828

# %%
courses.to_csv("CSV//courses.csv",index = False, sep=";")

# %% [markdown]
# Data Cleaning Badges DF

# %%
badges
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 0          <p>School offers fully online courses</p>  app-academy      10525
# 1  <p>School offers part-time and evening classes...  app-academy      10525
# 2             <p>School guarantees job placement</p>  app-academy      10525
# 0          <p>School offers fully online courses</p>  springboard      11035
# 1  <p>School offers part-time and evening classes...  springboard      11035
# 2             <p>School guarantees job placement</p>  springboard      11035

# %%
#badges = badges[['school_id','school','keyword', 'name','description']].copy()
badges['description'] = badges['description'].str.replace(r'(?<=<).*?(?=>)', '', regex = True)
badges['description'] = badges['description'].str.replace('<>', '', regex = True)
badges.reset_index(inplace = True, drop = True)
badges.index += 1

badges
# Out:
#                 name            keyword  \
# 1   Available Online   available_online
# 2  Verified Outcomes  verified_outcomes
# 3   Flexible Classes   flexible_classes
# 4   Available Online   available_online
# 5   Flexible Classes   flexible_classes
# 6      Job Guarantee      job_guarantee
# 7   Available Online   available_online
# 8   Flexible Classes   flexible_classes
# 9      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 1                 School offers fully online courses     ironhack      10828
# 2  School publishes a third-party verified outcom...     ironhack      10828
# 3        School offers part-time and evening classes     ironhack      10828
# 4                 School offers fully online courses  app-academy      10525
# 5        School offers part-time and evening classes  app-academy      10525
# 6                    School guarantees job placement  app-academy      10525
# 7                 School offers fully online courses  springboard      11035
# 8        School offers part-time and evening classes  springboard      11035
# 9                    School guarantees job placement  springboard      11035

# %% [markdown]
# Deleting some rows so that we have only unique values in 'name'

# %%
badges.drop(badges[badges['school_id'] == 10525].index, inplace=True)
badges.drop([7, 8], inplace=True)


badges
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Win10 Pro x64\Documents\Data_Weiterbildung\IronHack\03_Projects\01_SQL_Project\switchup_scraper_Dani.ipynb Cell 39 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Win10%20Pro%20x64/Documents/Data_Weiterbildung/IronHack/03_Projects/01_SQL_Project/switchup_scraper_Dani.ipynb#Y210sZmlsZQ%3D%3D?line=0'>1</a> badges.drop(badges[badges['school_id'] == 10525].index, inplace=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Win10%20Pro%20x64/Documents/Data_Weiterbildung/IronHack/03_Projects/01_SQL_Project/switchup_scraper_Dani.ipynb#Y210sZmlsZQ%3D%3D?line=1'>2</a> badges.drop([7, 8], inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Win10%20Pro%20x64/Documents/Data_Weiterbildung/IronHack/03_Projects/01_SQL_Project/switchup_scraper_Dani.ipynb#Y210sZmlsZQ%3D%3D?line=2'>3</a> badges.reset_index(inplace = True, drop = True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Win10%20Pro%20x64/Documents/Data_Weiterbildung/IronHack/03_Projects/01_SQL_Project/switchup_scraper_Dani.ipynb#Y210sZmlsZQ%3D%3D?line=3'>4</a> badges.index += 1
#
# File c:\Anaconda\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Anaconda\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File c:\Anaconda\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Anaconda\Lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File c:\Anaconda\Lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File c:\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: '[7, 8] not found in axis'

# %%
badges.reset_index(inplace = True, drop = True)
badges.index += 1
badges
# Out:
#                 name            keyword  \
# 1   Available Online   available_online
# 2  Verified Outcomes  verified_outcomes
# 3   Flexible Classes   flexible_classes
# 4      Job Guarantee      job_guarantee
#
#                                          description       school  school_id
# 1                 School offers fully online courses     ironhack      10828
# 2  School publishes a third-party verified outcom...     ironhack      10828
# 3        School offers part-time and evening classes     ironhack      10828
# 4                    School guarantees job placement  springboard      11035

# %% [markdown]
# Deleting columns we don`t need

# %%
badges.drop(columns=['keyword', 'school', 'school_id'], inplace=True)
badges
# Out:
#                 name                                        description
# 1   Available Online                 School offers fully online courses
# 2  Verified Outcomes  School publishes a third-party verified outcom...
# 3   Flexible Classes        School offers part-time and evening classes
# 4      Job Guarantee                    School guarantees job placement

# %% [markdown]
# Adding new column as a copy of index and renaming it 'badge_id'

# %%
badges['index'] = badges.index
badges.rename(columns={'index': 'badge_id'}, inplace=True)
badges = badges.reindex(columns=['badge_id', 'name', 'description'])
badges
# Out:
#    badge_id               name  \
# 1         1   Available Online
# 2         2  Verified Outcomes
# 3         3   Flexible Classes
# 4         4      Job Guarantee
#
#                                          description
# 1                 School offers fully online courses
# 2  School publishes a third-party verified outcom...
# 3        School offers part-time and evening classes
# 4                    School guarantees job placement

# %% [markdown]
# saving to .csv file

# %%
badges.to_csv("CSV//badges.csv",index = False, sep=";")

# %% [markdown]
# # Data Cleaning Comments DF

# %% [markdown]
# Deleting and Renaming columns

# %%
comments.head(3)
# Out:
#        id           name  anonymous hostProgramName  graduatingYear  isAlumni  \
# 0  306372  Sergio Burgos      False            None          2023.0     False
# 1  306215      Anonymous       True            None          2023.0      True
# 2  306068      Anonymous       True            None          2023.0     False
#
#                    jobTitle                                         tagline  \
# 0  International Negotiator             The Most Intense Academic Challenge
# 1                            Transformative Experience: My Time at Ironhack
# 2    Full stack development                                 Now I can do it
#
#                                                 body  \
# 0  <span class="truncatable"><p></p><p>After comp...
# 1  <span class="truncatable"><p></p><p>Pros: 1)In...
# 2  <span class="truncatable"><p></p><p>7 months a...
#
#                                              rawBody  ...   queryDate  \
# 0  <p>After completing my Data Analytics Bootcamp...  ...  2023-11-10
# 1  <p>Pros: 1)Intensive Learning 2)Real-World Pro...  ...  2023-11-06
# 2  <p>7 months ago, I only had an idea about html...  ...  2023-10-31
#
#                     program             user overallScore comments overall  \
# 0   Data Analytics Bootcamp  {'image': None}          3.3       []     3.0
# 1  Web Development Bootcamp  {'image': None}          4.0       []     4.0
# 2                      None  {'image': None}          5.0       []     5.0
#
#   curriculum jobSupport                                        review_body  \
# 0        3.0        4.0  After completing my Data Analytics Bootcamp wi...
# 1        4.0        4.0  Pros: 1)Intensive Learning 2)Real-World Projec...
# 2        5.0        5.0  7 months ago, I only had an idea about html an...
#
#      school
# 0  ironhack
# 1  ironhack
# 2  ironhack
#
# [3 rows x 21 columns]

# %%
comments.columns

# %% [markdown]
# Creating a copy of the original DF only with columns we need to match the columns in the MySQL DB

# %%
comments_new=comments[['id', 'name', 'anonymous', 'graduatingYear',
       'isAlumni', 'jobTitle', 'tagline', 'createdAt', 'program', 'overallScore', 'overall',
       'curriculum', 'jobSupport', 'review_body', 'school']]

comments_new.head(2)
# Out:
#        id           name  anonymous  graduatingYear  isAlumni  \
# 0  306372  Sergio Burgos      False          2023.0     False
# 1  306215      Anonymous       True          2023.0      True
#
#                    jobTitle                                         tagline  \
# 0  International Negotiator             The Most Intense Academic Challenge
# 1                            Transformative Experience: My Time at Ironhack
#
#     createdAt                   program overallScore overall curriculum  \
# 0  11/10/2023   Data Analytics Bootcamp          3.3     3.0        3.0
# 1   11/6/2023  Web Development Bootcamp          4.0     4.0        4.0
#
#   jobSupport                                        review_body    school
# 0        4.0  After completing my Data Analytics Bootcamp wi...  ironhack
# 1        4.0  Pros: 1)Intensive Learning 2)Real-World Projec...  ironhack

# %%
comments_new.rename(columns={'id':'comment_id', 'graduatingYear':'graduating_year',
       'isAlumni':'is_alumni', 'jobTitle':'job_title', 'tagline':'tag_line', 'createdAt':'date', 'program':'courses', 'overallScore':'overall_score', 'jobSupport':'job_support', 'review_body':'body'}, inplace=True)

comments_new.columns
# Out:
# C:\Users\Win10 Pro x64\AppData\Local\Temp\ipykernel_14148\620871338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comments_new.rename(columns={'id':'comment_id', 'graduatingYear':'graduating_year',
# Index(['comment_id', 'name', 'anonymous', 'graduating_year', 'is_alumni',
#        'job_title', 'tag_line', 'date', 'courses', 'overall_score', 'overall',
#        'curriculum', 'job_support', 'body', 'school'],
#       dtype='object')

# %% [markdown]
# reordering the columns so that they match with the tables in MySQL

# %%
comments_new = comments_new.reindex(columns=['comment_id', 'date', 'name', 'anonymous', 'graduating_year', 'is_alumni',
       'job_title', 'tag_line', 'body', 'courses', 'overall_score', 'overall',
       'curriculum', 'job_support', 'school'])

# %% [markdown]
# Creating a new column for student_id as a duplicate of the column 'name'

# %%
comments_new['student_id'] = comments_new.loc[:, 'name']

# %% [markdown]
# Assigning unique 5 digit values as student ids for every student name
# 'Anonymous' = 10001

# %%
comments_new['student_id'] = pd.factorize(comments_new['student_id'])[0] + 10000

# %% [markdown]
# reordering again

# %%
comments_new = comments_new.reindex(columns=['comment_id', 'student_id', 'date', 'name', 'anonymous', 'graduating_year',
       'is_alumni', 'job_title', 'tag_line', 'body', 'courses',
       'overall_score', 'overall', 'curriculum', 'job_support', 'school'
       ])

# %% [markdown]
# ## Checking for missing values

# %%
miss_val = pd.DataFrame(round(comments_new.isna().sum()/len(comments_new),4)*100)
miss_val = miss_val.reset_index()
miss_val.columns = ['column_name', 'percentage_of_missing_values']
display(miss_val)
# Out:
#         column_name  percentage_of_missing_values
# 0        comment_id                          0.00
# 1        student_id                          0.00
# 2              date                          0.00
# 3              name                          0.00
# 4         anonymous                          0.00
# 5   graduating_year                          0.10
# 6         is_alumni                          0.00
# 7         job_title                         35.20
# 8          tag_line                          0.02
# 9              body                          0.00
# 10          courses                          5.90
# 11    overall_score                          0.20
# 12          overall                          0.25
# 13       curriculum                          1.16
# 14      job_support                          7.11
# 15           school                          0.00

# %% [markdown]
# We can`t have missing values in the score columns, as we plan to use them for modelling, so we decided to drop those rows.

# %%
comments_new.dropna(subset=['overall_score'], inplace=True)
comments_new.dropna(subset=['overall'], inplace=True)
comments_new.dropna(subset=['curriculum'], inplace=True)
comments_new.dropna(subset=['job_support'], inplace=True)
comments_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3758 entries, 0 to 1564
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   comment_id       3758 non-null   int64
#  1   student_id       3758 non-null   int64
#  2   date             3758 non-null   object
#  3   name             3758 non-null   object
#  4   anonymous        3758 non-null   bool
#  5   graduating_year  3754 non-null   float64
#  6   is_alumni        3758 non-null   bool
#  7   job_title        2491 non-null   object
#  8   tag_line         3758 non-null   object
#  9   body             3758 non-null   object
#  10  courses          3556 non-null   object
#  11  overall_score    3758 non-null   object
#  12  overall          3758 non-null   object
#  13  curriculum       3758 non-null   object
#  14  job_support      3758 non-null   object
#  15  school           3758 non-null   object
# dtypes: bool(2), float64(1), int64(2), object(11)
# memory usage: 447.7+ KB

# %% [markdown]
# Adding 'schoo_id' column and assingning it`s values by mapping from a dictionary with the school_ids

# %%
comments_new['school_id'] = comments_new.loc[:, 'school']
school_idS = {   
'ironhack' : 10828,
'app-academy' : 10525,
'springboard' : 11035    
}
comments_new['school_id'] = comments_new['school_id'].map(school_idS)

# %% [markdown]
# Adding 'course_id' column and assingning it`s values by mapping from a dictionary with the course_ids

# %%
comments_new['course_id'] = comments_new.loc[:, 'courses']
course_id_mapping=courses.set_index('course')['course_id'].to_dict()
comments_new['course_id'] = comments_new['course_id'].map(course_id_mapping)
# Out:
#       comment_id  student_id        date           name  anonymous  \
# 0         306372       10000  11/10/2023  Sergio Burgos      False
# 1         306215       10001   11/6/2023      Anonymous       True
# 2         306068       10001  10/31/2023      Anonymous       True
# 3         305297       10002   10/2/2023    Utku Cikmaz      False
# 4         305278       10003   9/30/2023   Nirmal Hodge      False
# ...          ...         ...         ...            ...        ...
# 1560      234894       13138  12/15/2016   Stephanie S.      False
# 1561      234877       13139  12/15/2016       Joe Fang      False
# 1562      234838       13140  12/15/2016          Zeina      False
# 1563      242681       13141  12/12/2016           Jean      False
# 1564      234178       11277  12/10/2016            Ben      False
#
#       graduating_year  is_alumni                        job_title  \
# 0              2023.0      False         International Negotiator
# 1              2023.0       True
# 2              2023.0      False           Full stack development
# 3              2023.0      False         Full Stack Web Developer
# 4              2023.0      False                 Product Designer
# ...               ...        ...                              ...
# 1560           2015.0       True          Website Manager-UX Lead
# 1561           2015.0       True                      UX Designer
# 1562           2016.0       True          Senior Graphic Designer
# 1563           2016.0       True  Lead Designer/Creative Director
# 1564           2016.0       True                             None
#
#                                                tag_line  \
# 0                   The Most Intense Academic Challenge
# 1        Transformative Experience: My Time at Ironhack
# 2                                       Now I can do it
# 3                                           It was good
# 4                               Ironhack 100% Worth It!
# ...                                                 ...
# 1560              Excellent and comprehensive UX course
# 1561        Springboard helped me start my career in UX
# 1562                                 Highly recommended
# 1563    A way to stay current for the highly motivated!
# 1564  Springboard is an excellent course for self dr...
#
#                                                    body  \
# 0     After completing my Data Analytics Bootcamp wi...
# 1     Pros: 1)Intensive Learning 2)Real-World Projec...
# 2     7 months ago, I only had an idea about html an...
# 3     The course was great. Especially, Luis is a gr...
# 4     I joined the UX/ UI Bootcamp and to be honest ...
# ...                                                 ...
# 1560  The UX Design Workshop gave me a great underst...
# 1561  Just some background information on myself, I ...
# 1562  I enjoyed the program very much, gained a lot ...
# 1563  This was my first online experience and it did...
# 1564  I really enjoyed my time with the Springboard ...
#
#                        courses overall_score overall curriculum job_support  \
# 0      Data Analytics Bootcamp           3.3     3.0        3.0         4.0
# 1     Web Development Bootcamp           4.0     4.0        4.0         4.0
# 2                         None           5.0     5.0        5.0         5.0
# 3     Web Development Bootcamp           4.0     5.0        3.0         4.0
# 4        UX/UI Design Bootcamp           5.0     5.0        5.0         5.0
# ...                        ...           ...     ...        ...         ...
# 1560                 UX Design           5.0     5.0        5.0         5.0
# 1561                 UX Design           5.0     5.0        5.0         5.0
# 1562                 UX Design           3.7     4.0        4.0         3.0
# 1563                 UX Design           5.0     5.0        5.0         5.0
# 1564                 UX Design           4.7     5.0        5.0         4.0
#
#            school  school_id  course_id
# 0        ironhack      10828        3.0
# 1        ironhack      10828        7.0
# 2        ironhack      10828        NaN
# 3        ironhack      10828        7.0
# 4        ironhack      10828        5.0
# ...           ...        ...        ...
# 1560  springboard      11035        NaN
# 1561  springboard      11035        NaN
# 1562  springboard      11035        NaN
# 1563  springboard      11035        NaN
# 1564  springboard      11035        NaN
#
# [3758 rows x 18 columns]

# %%
comments_new.head(3)
# Out:
#    comment_id  student_id        date           name  anonymous  \
# 0      306372       10000  11/10/2023  Sergio Burgos      False
# 1      306215       10001   11/6/2023      Anonymous       True
# 2      306068       10001  10/31/2023      Anonymous       True
#
#    graduating_year  is_alumni                 job_title  \
# 0           2023.0      False  International Negotiator
# 1           2023.0       True
# 2           2023.0      False    Full stack development
#
#                                          tag_line  \
# 0             The Most Intense Academic Challenge
# 1  Transformative Experience: My Time at Ironhack
# 2                                 Now I can do it
#
#                                                 body  \
# 0  After completing my Data Analytics Bootcamp wi...
# 1  Pros: 1)Intensive Learning 2)Real-World Projec...
# 2  7 months ago, I only had an idea about html an...
#
#                     courses overall_score overall curriculum job_support  \
# 0   Data Analytics Bootcamp           3.3     3.0        3.0         4.0
# 1  Web Development Bootcamp           4.0     4.0        4.0         4.0
# 2                      None           5.0     5.0        5.0         5.0
#
#      school  school_id  course_id
# 0  ironhack      10828        3.0
# 1  ironhack      10828        7.0
# 2  ironhack      10828        NaN

# %%
comments_new['graduating_year'] = pd.to_numeric(comments_new['graduating_year'], errors='coerce').astype('Int64')

# %% [markdown]
# Creating a .csv file

# %%
comments_new.to_csv("CSV/comments_new.csv",index = False, sep=";")

# %% [markdown]
# creating a new 'students' DF as a copy of the needed columns from the comments DF

# %%
students=comments_new[['student_id', 'name', 'job_title', 'graduating_year', 'school_id', 'course_id']]
students.head(3)
# Out:
#    student_id           name                 job_title  graduating_year  \
# 0       10000  Sergio Burgos  International Negotiator             2023
# 1       10001      Anonymous                                       2023
# 2       10001      Anonymous    Full stack development             2023
#
#    school_id  course_id
# 0      10828        3.0
# 1      10828        7.0
# 2      10828        NaN

# %% [markdown]
# Deleting the 'anonymous' students and dropping duplicates

# %%
students = students.drop(students[students['student_id'] == 10001].index)
students = students.drop_duplicates(subset='student_id', keep='first')

# %% [markdown]
# creating the students_courses table and saving as csv

# %%
students_courses = students[['student_id', 'course_id']]
students_courses
# Out:
#       student_id  course_id
# 0          10000        3.0
# 3          10002        7.0
# 4          10003        5.0
# 7          10004        4.0
# 13         10009        7.0
# ...          ...        ...
# 1559       13137        NaN
# 1560       13138        NaN
# 1561       13139        NaN
# 1562       13140        NaN
# 1563       13141        NaN
#
# [2008 rows x 2 columns]

# %%
students_courses.to_csv("CSV/students_courses.csv",index = False, sep=";")

# %%
students.drop(columns=['course_id'], inplace=True)
students
# Out:
#       student_id                   name                        job_title  \
# 0          10000          Sergio Burgos         International Negotiator
# 3          10002            Utku Cikmaz         Full Stack Web Developer
# 4          10003           Nirmal Hodge                 Product Designer
# 7          10004          Sabir Karimov                     Data Analyst
# 13         10009  Mercedes Amor Gallart
# ...          ...                    ...                              ...
# 1559       13137               Jenny N.                             None
# 1560       13138           Stephanie S.          Website Manager-UX Lead
# 1561       13139               Joe Fang                      UX Designer
# 1562       13140                  Zeina          Senior Graphic Designer
# 1563       13141                   Jean  Lead Designer/Creative Director
#
#       graduating_year  school_id
# 0                2023      10828
# 3                2023      10828
# 4                2023      10828
# 7                2023      10828
# 13               2023      10828
# ...               ...        ...
# 1559             2016      11035
# 1560             2015      11035
# 1561             2015      11035
# 1562             2016      11035
# 1563             2016      11035
#
# [2008 rows x 5 columns]

# %%
students.to_csv("CSV/students.csv",index = False, sep=";")
